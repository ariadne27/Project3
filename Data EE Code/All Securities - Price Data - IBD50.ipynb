# %%
import http.client
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

key = "OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm"
key2 = "OmNkNmI1NzJhYmUxODJlODBjMWIwOGI1ZjZiNzcxMDkw"
prod_key = "OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm"
co_code = ""

# %%
tickers_df = pd.read_csv("IBD 50.csv")

# %%
filtered_df = tickers_df[tickers_df['Symbol'].notnull()]
filtered_df
# Out:
#    Symbol              Company Name  Rank
# 0      KL    Kirkland Lake Gold Ltd     1
# 1      RH                       R H     2
# 2    CPRT                COPART INC     3
# 3     MTZ                MASTEC INC     4
# 4    PCTY    Paylocity Holding Corp     5
# 5    ESNT          Essent Group Ltd     6
# 6      EW      Edwards Lifesciences     7
# 7     EDU  NEW ORIENTL EDU&TECH ADS     8
# 8    PAYC       Paycom Software Inc     9
# 9     CDW                       CDW    10
# 10   LULU       LULULEMON ATHLETICA    11
# 11   BOOT    Boot Barn Holdings Inc    12
# 12   VEEV    Veeva Systems Inc Cl A    13
# 13   OLED    UNIVERSAL DISPLAY CORP    14
# 14    HEI                HEICO CORP    15
# 15   REXR   Rexford Industrial Rlty    16
# 16   SEDG    Solaredge Technologies    17
# 17   INMD                Inmode Ltd    18
# 18    LHX     L3Harris Technologies    19
# 19    FLT     Fleetcor Technologies    20
# 20    FSS       FEDERAL SIGNAL CORP    21
# 21   EPRT  Essential Prop Realty Tr    22
# 22    TPX     Tempur Sealy Intl Inc    23
# 23      V             VISA INC CL A    24
# 24   MSFT            MICROSOFT CORP    25
# 25  CMCSA         COMCAST CORP CL A    26
# 26    JPM     J P MORGAN CHASE & CO    27
# 27   JCOM            J 2 Global Inc    28
# 28    SYK              STRYKER CORP    29
# 29   CTRE            Caretrust Reit    30
# 30   STNE          Stoneco Ltd Cl A    31
# 31   EEFT     EURONET WORLDWIDE INC    32
# 32    TKR                 TIMKEN CO    33
# 33    BRO         BROWN & BROWN INC    34
# 34   STOR        Store Capital Corp    35
# 35   PYPL       Paypal Holdings Inc    36
# 36   BZUN       Baozun Inc Cl A Ads    37
# 37     WH  Wyndham Hotels & Resorts    38
# 38   UPLD       Upland Software Inc    39
# 39     RP              Realpage Inc    40
# 40   FTNT              FORTINET INC    41
# 41   ADBE                 Adobe Inc    42
# 42    CRM        SALESFORCE.COM INC    43
# 43   MOMO         Momo Inc Ads Cl A    44
# 44   ANET       Arista Networks Inc    45
# 45   CHGG                 Chegg Inc    46
# 46   CVBF      C V B FINANCIAL CORP    47
# 47   SSNC      S S & C TECHNOLOGIES    48
# 48   HUYA         Huya Inc Cl A Ads    49
# 49   ALXN   ALEXION PHARMACEUTICALS    50

# %%
tickers = filtered_df["Symbol"].tolist()
ticker_ct = len(tickers)
ticker_ct
# Out:
# 50

# %%
tickers[0]
# Out:
# 'KL'

# %% [markdown]
# {"date":"2019-10-23",
#  "intraperiod":false,
#  "frequency":"daily",
#  "open":242.1,
#  "high":243.24,"low":241.22,"close":243.18,"volume":18933571.0,"adj_open":242.1,"adj_high":243.24,
#  "adj_low":241.22,"adj_close":243.18,"adj_volume":18933571.0}

# %%
import sys, requests, json, time, random
ticker_df = []
date_df = []
intraperiod_df = []
frequency_df = []
open_df = []
high_df = []
low_df = []
close_df = []
volume_df = []
adj_open_df = []
adj_high_df = []
adj_low_df = []
adj_close_df = []
adj_volume_df = []

        
for i in range (0, ticker_ct):
    print("Ticker")
    print(i)
    nunya = "test"
    co_code = tickers[i]
    print(co_code)
    try:
        url = "https://api-v2.intrinio.com/securities/" + co_code +"/prices?api_key=" + prod_key + "&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23"
        print(url)
        JSONContent = requests.get(url).json()
        sec_ct = len(JSONContent['stock_prices'])
        print(sec_ct)
    except (TypeError):
        print("Type Error")
        continue
    except (requests.exceptions.ConnectionError, json.decoder.JSONDecodeError):
        time.sleep(20)
        print("Connection, JSON Decode")
        JSONContent = requests.get(url).json()
        sec_ct = len(JSONContent['stock_prices'])
        print(sec_ct)
        continue
    except KeyError as e:
        time.sleep(20)
        print("KeyError")
        JSONContent = requests.get(url).json()
        sec_ct = len(JSONContent['stock_prices'])
        print(sec_ct)
        continue
        
    while nunya is not None:
        for j in range (0, sec_ct):
            date = JSONContent["stock_prices"][j]["date"]
            intraperiod = JSONContent["stock_prices"][j]["intraperiod"]
            frequency = JSONContent["stock_prices"][j]["frequency"]
            open = JSONContent["stock_prices"][j]["open"]
            high = JSONContent["stock_prices"][j]["high"]
            low = JSONContent["stock_prices"][j]["low"]
            close = JSONContent["stock_prices"][j]["close"]
            volume = JSONContent["stock_prices"][j]["volume"]
            adj_open = JSONContent["stock_prices"][j]["adj_open"]
            adj_high = JSONContent["stock_prices"][j]["adj_high"]
            adj_low = JSONContent["stock_prices"][j]["adj_low"]
            adj_close = JSONContent["stock_prices"][j]["adj_close"]
            adj_volume = JSONContent["stock_prices"][j]["adj_volume"]
            nunya = JSONContent["next_page"]
            # appendall 
            ticker_df.append(co_code)
            date_df.append(date)
            intraperiod_df.append(intraperiod)
            frequency_df.append(frequency)
            open_df.append(open)
            high_df.append(high)
            low_df.append(low)
            close_df.append(close)
            volume_df.append(volume)
            adj_open_df.append(adj_open)
            adj_high_df.append(adj_high)
            adj_low_df.append(adj_low)
            adj_close_df.append(adj_close)
            adj_volume_df.append(adj_volume)

        if nunya is not None: 
            try:
                url = "https://api-v2.intrinio.com/securities/" + co_code +"/prices?api_key=" + prod_key + "&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23" + "&next_page=" + nunya
                print(url)
                JSONContent = requests.get(url).json()
                sec_ct = len(JSONContent['stock_prices'])   
            except (requests.exceptions.ConnectionError, json.decoder.JSONDecodeError):
                print("Connection, JSON Decode")
                time.sleep(20)
                JSONContent = requests.get(url).json()
                sec_ct = len(JSONContent['stock_prices'])
                print(sec_ct)
                print("nunya: " + nunya)
                continue        
            except KeyError as e:
                print("Key Error")
                time.sleep(20)
                JSONContent = requests.get(url).json()
                sec_ct = len(JSONContent['stock_prices'])
                print(sec_ct)
                print("nunya: " + nunya)
                continue
# Out:
# Ticker
# 0
# KL
# https://api-v2.intrinio.com/securities/KL/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 26
# Ticker
# 1
# RH
# https://api-v2.intrinio.com/securities/RH/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 83
# Ticker
# 2
# CPRT
# https://api-v2.intrinio.com/securities/CPRT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/CPRT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQxMTA2NTM3
# Ticker
# 3
# MTZ
# https://api-v2.intrinio.com/securities/MTZ/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/MTZ/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjU4NjAzMTI2
# Ticker
# 4
# PCTY
# https://api-v2.intrinio.com/securities/PCTY/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 67
# Ticker
# 5
# ESNT
# https://api-v2.intrinio.com/securities/ESNT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 72
# Ticker
# 6
# EW
# https://api-v2.intrinio.com/securities/EW/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/EW/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQ0NjI0NDQ3
# Ticker
# 7
# EDU
# https://api-v2.intrinio.com/securities/EDU/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/EDU/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQzNDA2OTI3
# Ticker
# 8
# PAYC
# https://api-v2.intrinio.com/securities/PAYC/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 66
# Ticker
# 9
# CDW
# https://api-v2.intrinio.com/securities/CDW/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 76
# Ticker
# 10
# LULU
# https://api-v2.intrinio.com/securities/LULU/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/LULU/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjU2NTEyMTkz
# Ticker
# 11
# BOOT
# https://api-v2.intrinio.com/securities/BOOT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 60
# Ticker
# 12
# VEEV
# https://api-v2.intrinio.com/securities/VEEV/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 72
# Ticker
# 13
# OLED
# https://api-v2.intrinio.com/securities/OLED/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/OLED/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjYwODYzNjg0
# Ticker
# 14
# HEI
# https://api-v2.intrinio.com/securities/HEI/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/HEI/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjUxNjcyMTg0
# Ticker
# 15
# REXR
# https://api-v2.intrinio.com/securities/REXR/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 75
# Ticker
# 16
# SEDG
# https://api-v2.intrinio.com/securities/SEDG/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 55
# Ticker
# 17
# INMD
# https://api-v2.intrinio.com/securities/INMD/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 2
# Ticker
# 18
# LHX
# https://api-v2.intrinio.com/securities/LHX/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/LHX/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHwxMTE5OTM0ODgyMw==
# Ticker
# 19
# FLT
# https://api-v2.intrinio.com/securities/FLT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/FLT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQ1NjAxNzk3
# Ticker
# 20
# FSS
# https://api-v2.intrinio.com/securities/FSS/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/FSS/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjQ5NzEyMjQz
# Ticker
# 21
# EPRT
# https://api-v2.intrinio.com/securities/EPRT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 16
# Ticker
# 22
# TPX
# https://api-v2.intrinio.com/securities/TPX/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/TPX/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjY5MjgzMTcy
# Ticker
# 23
# V
# https://api-v2.intrinio.com/securities/V/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/V/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHwxMDgwMjc4OTU0OA==
# Ticker
# 24
# MSFT
# https://api-v2.intrinio.com/securities/MSFT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/MSFT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHwxMTQ2OTg4ODAzMg==
# Ticker
# 25
# CMCSA
# https://api-v2.intrinio.com/securities/CMCSA/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/CMCSA/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQwNjMzNDI3
# Ticker
# 26
# JPM
# https://api-v2.intrinio.com/securities/JPM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/JPM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHwxMTU4OTY5MTkwNA==
# Ticker
# 27
# JCOM
# https://api-v2.intrinio.com/securities/JCOM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/JCOM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjU0NTAzNDEx
# Ticker
# 28
# SYK
# https://api-v2.intrinio.com/securities/SYK/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/SYK/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjY4MjQ0NDkw
# Ticker
# 29
# CTRE
# https://api-v2.intrinio.com/securities/CTRE/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 65
# Ticker
# 30
# STNE
# https://api-v2.intrinio.com/securities/STNE/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 12
# Ticker
# 31
# EEFT
# https://api-v2.intrinio.com/securities/EEFT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/EEFT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQzNDUxNTYy
# Ticker
# 32
# TKR
# https://api-v2.intrinio.com/securities/TKR/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/TKR/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjY5MDk0MzAy
# Ticker
# 33
# BRO
# https://api-v2.intrinio.com/securities/BRO/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/BRO/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTM4OTA4ODk1
# Ticker
# 34
# STOR
# https://api-v2.intrinio.com/securities/STOR/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 59
# Ticker
# 35
# PYPL
# https://api-v2.intrinio.com/securities/PYPL/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 51
# Ticker
# 36
# BZUN
# https://api-v2.intrinio.com/securities/BZUN/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 53
# Ticker
# 37
# WH
# https://api-v2.intrinio.com/securities/WH/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 16
# Ticker
# 38
# UPLD
# https://api-v2.intrinio.com/securities/UPLD/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 59
# Ticker
# 39
# RP
# https://api-v2.intrinio.com/securities/RP/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/RP/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjY0NzI0NTY5
# Ticker
# 40
# FTNT
# https://api-v2.intrinio.com/securities/FTNT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/FTNT/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjQ5NjcyNzM5
# Ticker
# 41
# ADBE
# https://api-v2.intrinio.com/securities/ADBE/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/ADBE/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTM1NTAxNTkx
# Ticker
# 42
# CRM
# https://api-v2.intrinio.com/securities/CRM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/CRM/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQxMjY0OTAz
# Ticker
# 43
# MOMO
# https://api-v2.intrinio.com/securities/MOMO/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 58
# Ticker
# 44
# ANET
# https://api-v2.intrinio.com/securities/ANET/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 64
# Ticker
# 45
# CHGG
# https://api-v2.intrinio.com/securities/CHGG/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 71
# Ticker
# 46
# CVBF
# https://api-v2.intrinio.com/securities/CVBF/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/CVBF/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTQxNzA4OTMy
# Ticker
# 47
# SSNC
# https://api-v2.intrinio.com/securities/SSNC/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/SSNC/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw0MjY3NTkxMDM0
# Ticker
# 48
# HUYA
# https://api-v2.intrinio.com/securities/HUYA/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 17
# Ticker
# 49
# ALXN
# https://api-v2.intrinio.com/securities/ALXN/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23
# 100
# https://api-v2.intrinio.com/securities/ALXN/prices?api_key=OmZkNWQxNDI2M2ViMjAzNzJlNTQ0MWNkMmQxNjJhNzNm&frequency=monthly&start_date=2007-01-01&end_date=2019-10-23&next_page=MjAxMS0wNi0zMHw4NTM2MjY1NzI2

# %%
ticker_df
# Out:
# ['KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'KL',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'RH',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'CPRT',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'MTZ',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'PCTY',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'ESNT',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EW',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'EDU',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'PAYC',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  'CDW',
#  ...]

# %%
JSONContent
# Out:
# {'stock_prices': [{'date': '2011-05-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 96.97,
#    'high': 101.96,
#    'low': 44.36,
#    'close': 47.42,
#    'volume': 18820800.0,
#    'adj_open': 48.485,
#    'adj_high': 50.98,
#    'adj_low': 44.36,
#    'adj_close': 47.42,
#    'adj_volume': 28959200.0},
#   {'date': '2011-04-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 99.38,
#    'high': 105.0,
#    'low': 92.94,
#    'close': 96.87,
#    'volume': 21526400.0,
#    'adj_open': 49.69,
#    'adj_high': 52.5,
#    'adj_low': 46.47,
#    'adj_close': 48.435,
#    'adj_volume': 43052800.0},
#   {'date': '2011-03-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 96.93,
#    'high': 100.36,
#    'low': 92.81,
#    'close': 98.68,
#    'volume': 17825700.0,
#    'adj_open': 48.465,
#    'adj_high': 50.18,
#    'adj_low': 46.405,
#    'adj_close': 49.34,
#    'adj_volume': 35651400.0},
#   {'date': '2011-02-28',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 84.36,
#    'high': 96.94,
#    'low': 83.29,
#    'close': 96.28,
#    'volume': 13742800.0,
#    'adj_open': 42.18,
#    'adj_high': 48.47,
#    'adj_low': 41.645,
#    'adj_close': 48.14,
#    'adj_volume': 27485600.0},
#   {'date': '2011-01-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 81.36,
#    'high': 87.1393,
#    'low': 80.08,
#    'close': 83.82,
#    'volume': 11743600.0,
#    'adj_open': 40.68,
#    'adj_high': 43.56965,
#    'adj_low': 40.04,
#    'adj_close': 41.91,
#    'adj_volume': 23487200.0},
#   {'date': '2010-12-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 76.78,
#    'high': 83.62,
#    'low': 74.93,
#    'close': 80.55,
#    'volume': 17676800.0,
#    'adj_open': 38.39,
#    'adj_high': 41.81,
#    'adj_low': 37.465,
#    'adj_close': 40.275,
#    'adj_volume': 35353600.0},
#   {'date': '2010-11-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 68.59,
#    'high': 77.64,
#    'low': 66.96,
#    'close': 76.45,
#    'volume': 21750700.0,
#    'adj_open': 34.295,
#    'adj_high': 38.82,
#    'adj_low': 33.48,
#    'adj_close': 38.225,
#    'adj_volume': 43501400.0},
#   {'date': '2010-10-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 64.57,
#    'high': 72.45,
#    'low': 62.86,
#    'close': 68.3,
#    'volume': 20641200.0,
#    'adj_open': 32.285,
#    'adj_high': 36.225,
#    'adj_low': 31.43,
#    'adj_close': 34.15,
#    'adj_volume': 41282400.0},
#   {'date': '2010-09-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 57.46,
#    'high': 65.38,
#    'low': 57.33,
#    'close': 64.36,
#    'volume': 14411800.0,
#    'adj_open': 28.73,
#    'adj_high': 32.69,
#    'adj_low': 28.665,
#    'adj_close': 32.18,
#    'adj_volume': 28823600.0},
#   {'date': '2010-08-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 54.71,
#    'high': 58.67,
#    'low': 54.06,
#    'close': 56.47,
#    'volume': 12669600.0,
#    'adj_open': 27.355,
#    'adj_high': 29.335,
#    'adj_low': 27.03,
#    'adj_close': 28.235,
#    'adj_volume': 25339200.0},
#   {'date': '2010-07-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 51.19,
#    'high': 54.99,
#    'low': 48.61,
#    'close': 54.36,
#    'volume': 16746400.0,
#    'adj_open': 25.595,
#    'adj_high': 27.495,
#    'adj_low': 24.305,
#    'adj_close': 27.18,
#    'adj_volume': 33492800.0},
#   {'date': '2010-06-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 49.49,
#    'high': 55.14,
#    'low': 48.84,
#    'close': 51.19,
#    'volume': 17022700.0,
#    'adj_open': 24.745,
#    'adj_high': 27.57,
#    'adj_low': 24.42,
#    'adj_close': 25.595,
#    'adj_volume': 34045400.0},
#   {'date': '2010-05-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 54.97,
#    'high': 55.8,
#    'low': 45.18,
#    'close': 50.03,
#    'volume': 17651600.0,
#    'adj_open': 27.485,
#    'adj_high': 27.9,
#    'adj_low': 22.59,
#    'adj_close': 25.015,
#    'adj_volume': 35303200.0},
#   {'date': '2010-04-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 54.53,
#    'high': 57.1999,
#    'low': 53.64,
#    'close': 54.88,
#    'volume': 10915700.0,
#    'adj_open': 27.265,
#    'adj_high': 28.59995,
#    'adj_low': 26.82,
#    'adj_close': 27.44,
#    'adj_volume': 21831400.0},
#   {'date': '2010-03-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 49.47,
#    'high': 56.3,
#    'low': 49.33,
#    'close': 54.37,
#    'volume': 14481500.0,
#    'adj_open': 24.735,
#    'adj_high': 28.15,
#    'adj_low': 24.665,
#    'adj_close': 27.185,
#    'adj_volume': 28963000.0},
#   {'date': '2010-02-28',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 46.3,
#    'high': 50.31,
#    'low': 45.7,
#    'close': 49.52,
#    'volume': 13133600.0,
#    'adj_open': 23.15,
#    'adj_high': 25.155,
#    'adj_low': 22.85,
#    'adj_close': 24.76,
#    'adj_volume': 26267200.0},
#   {'date': '2010-01-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 49.01,
#    'high': 49.57,
#    'low': 44.86,
#    'close': 46.37,
#    'volume': 10658700.0,
#    'adj_open': 24.505,
#    'adj_high': 24.785,
#    'adj_low': 22.43,
#    'adj_close': 23.185,
#    'adj_volume': 21317400.0},
#   {'date': '2009-12-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 45.46,
#    'high': 49.52,
#    'low': 44.48,
#    'close': 48.82,
#    'volume': 8824200.0,
#    'adj_open': 22.73,
#    'adj_high': 24.76,
#    'adj_low': 22.24,
#    'adj_close': 24.41,
#    'adj_volume': 17648400.0},
#   {'date': '2009-11-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 44.78,
#    'high': 45.71,
#    'low': 43.0,
#    'close': 45.38,
#    'volume': 12220500.0,
#    'adj_open': 22.39,
#    'adj_high': 22.855,
#    'adj_low': 21.5,
#    'adj_close': 22.69,
#    'adj_volume': 24441000.0},
#   {'date': '2009-10-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 44.29,
#    'high': 48.93,
#    'low': 43.07,
#    'close': 44.41,
#    'volume': 17096600.0,
#    'adj_open': 22.145,
#    'adj_high': 24.465,
#    'adj_low': 21.535,
#    'adj_close': 22.205,
#    'adj_volume': 34193200.0},
#   {'date': '2009-09-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 45.91,
#    'high': 47.0,
#    'low': 43.51,
#    'close': 44.54,
#    'volume': 12613100.0,
#    'adj_open': 22.955,
#    'adj_high': 23.5,
#    'adj_low': 21.755,
#    'adj_close': 22.27,
#    'adj_volume': 25226200.0},
#   {'date': '2009-08-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 44.36,
#    'high': 46.23,
#    'low': 41.67,
#    'close': 45.13,
#    'volume': 12764200.0,
#    'adj_open': 22.18,
#    'adj_high': 23.115,
#    'adj_low': 20.835,
#    'adj_close': 22.565,
#    'adj_volume': 25528400.0},
#   {'date': '2009-07-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 40.79,
#    'high': 44.69,
#    'low': 36.71,
#    'close': 44.05,
#    'volume': 26066500.0,
#    'adj_open': 20.395,
#    'adj_high': 22.345,
#    'adj_low': 18.355,
#    'adj_close': 22.025,
#    'adj_volume': 52133000.0},
#   {'date': '2009-06-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 36.77,
#    'high': 41.37,
#    'low': 36.11,
#    'close': 41.11,
#    'volume': 38363300.0,
#    'adj_open': 18.385,
#    'adj_high': 20.685,
#    'adj_low': 18.055,
#    'adj_close': 20.555,
#    'adj_volume': 76726600.0},
#   {'date': '2009-05-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 33.45,
#    'high': 36.5,
#    'low': 32.255,
#    'close': 36.5,
#    'volume': 23697900.0,
#    'adj_open': 16.725,
#    'adj_high': 18.25,
#    'adj_low': 16.1275,
#    'adj_close': 18.25,
#    'adj_volume': 47395800.0},
#   {'date': '2009-04-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 36.91,
#    'high': 38.32,
#    'low': 32.88,
#    'close': 33.42,
#    'volume': 25341100.0,
#    'adj_open': 18.455,
#    'adj_high': 19.16,
#    'adj_low': 16.44,
#    'adj_close': 16.71,
#    'adj_volume': 50682200.0},
#   {'date': '2009-03-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 34.0,
#    'high': 39.51,
#    'low': 30.78,
#    'close': 37.66,
#    'volume': 22588000.0,
#    'adj_open': 17.0,
#    'adj_high': 19.755,
#    'adj_low': 15.39,
#    'adj_close': 18.83,
#    'adj_volume': 45176000.0},
#   {'date': '2009-02-28',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 36.48,
#    'high': 40.59,
#    'low': 33.92,
#    'close': 34.2,
#    'volume': 21688300.0,
#    'adj_open': 18.24,
#    'adj_high': 20.295,
#    'adj_low': 16.96,
#    'adj_close': 17.1,
#    'adj_volume': 43376600.0},
#   {'date': '2009-01-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 35.41,
#    'high': 37.99,
#    'low': 34.04,
#    'close': 36.87,
#    'volume': 19167000.0,
#    'adj_open': 17.705,
#    'adj_high': 18.995,
#    'adj_low': 17.02,
#    'adj_close': 18.435,
#    'adj_volume': 38334000.0},
#   {'date': '2008-12-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 32.84,
#    'high': 36.43,
#    'low': 30.0,
#    'close': 36.19,
#    'volume': 17402400.0,
#    'adj_open': 16.42,
#    'adj_high': 18.215,
#    'adj_low': 15.0,
#    'adj_close': 18.095,
#    'adj_volume': 34804800.0},
#   {'date': '2008-11-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 40.73,
#    'high': 43.0,
#    'low': 28.16,
#    'close': 33.66,
#    'volume': 25804900.0,
#    'adj_open': 20.365,
#    'adj_high': 21.5,
#    'adj_low': 14.08,
#    'adj_close': 16.83,
#    'adj_volume': 51609800.0},
#   {'date': '2008-10-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 39.08,
#    'high': 43.29,
#    'low': 33.0,
#    'close': 40.75,
#    'volume': 31932100.0,
#    'adj_open': 19.54,
#    'adj_high': 21.645,
#    'adj_low': 16.5,
#    'adj_close': 20.375,
#    'adj_volume': 63864200.0},
#   {'date': '2008-09-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 45.64,
#    'high': 46.77,
#    'low': 35.92,
#    'close': 39.3,
#    'volume': 30155000.0,
#    'adj_open': 22.82,
#    'adj_high': 23.385,
#    'adj_low': 17.96,
#    'adj_close': 19.65,
#    'adj_volume': 60310000.0},
#   {'date': '2008-08-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 94.0,
#    'high': 95.91,
#    'low': 42.17,
#    'close': 45.08,
#    'volume': 19624000.0,
#    'adj_open': 23.5,
#    'adj_high': 23.9775,
#    'adj_low': 21.085,
#    'adj_close': 22.54,
#    'adj_volume': 70753800.0},
#   {'date': '2008-07-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 72.25,
#    'high': 94.91,
#    'low': 71.45,
#    'close': 93.75,
#    'volume': 21804500.0,
#    'adj_open': 18.0625,
#    'adj_high': 23.7275,
#    'adj_low': 17.8625,
#    'adj_close': 23.4375,
#    'adj_volume': 87218000.0},
#   {'date': '2008-06-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 71.0,
#    'high': 73.89,
#    'low': 66.85,
#    'close': 72.5,
#    'volume': 10912400.0,
#    'adj_open': 17.75,
#    'adj_high': 18.4725,
#    'adj_low': 16.7125,
#    'adj_close': 18.125,
#    'adj_volume': 43649600.0},
#   {'date': '2008-05-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 70.0,
#    'high': 74.22,
#    'low': 66.6,
#    'close': 71.35,
#    'volume': 13013400.0,
#    'adj_open': 17.5,
#    'adj_high': 18.555,
#    'adj_low': 16.65,
#    'adj_close': 17.8375,
#    'adj_volume': 52053600.0},
#   {'date': '2008-04-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 59.2,
#    'high': 71.5,
#    'low': 59.18,
#    'close': 70.38,
#    'volume': 15541700.0,
#    'adj_open': 14.8,
#    'adj_high': 17.875,
#    'adj_low': 14.795,
#    'adj_close': 17.595,
#    'adj_volume': 62166800.0},
#   {'date': '2008-03-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 59.97,
#    'high': 60.97,
#    'low': 49.26,
#    'close': 59.3,
#    'volume': 19941000.0,
#    'adj_open': 14.9925,
#    'adj_high': 15.2425,
#    'adj_low': 12.315,
#    'adj_close': 14.825,
#    'adj_volume': 79764000.0},
#   {'date': '2008-02-29',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 65.56,
#    'high': 74.45,
#    'low': 57.76,
#    'close': 60.61,
#    'volume': 25356200.0,
#    'adj_open': 16.39,
#    'adj_high': 18.6125,
#    'adj_low': 14.44,
#    'adj_close': 15.1525,
#    'adj_volume': 101424800.0},
#   {'date': '2008-01-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 75.23,
#    'high': 78.0,
#    'low': 61.79,
#    'close': 65.32,
#    'volume': 19451100.0,
#    'adj_open': 18.8075,
#    'adj_high': 19.5,
#    'adj_low': 15.4475,
#    'adj_close': 16.33,
#    'adj_volume': 77804400.0},
#   {'date': '2007-12-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 73.01,
#    'high': 77.86,
#    'low': 70.1,
#    'close': 75.03,
#    'volume': 8856600.0,
#    'adj_open': 18.2525,
#    'adj_high': 19.465,
#    'adj_low': 17.525,
#    'adj_close': 18.7575,
#    'adj_volume': 35426400.0},
#   {'date': '2007-11-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 76.18,
#    'high': 77.22,
#    'low': 67.95,
#    'close': 72.72,
#    'volume': 12348700.0,
#    'adj_open': 19.045,
#    'adj_high': 19.305,
#    'adj_low': 16.9875,
#    'adj_close': 18.18,
#    'adj_volume': 49394800.0},
#   {'date': '2007-10-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 64.85,
#    'high': 80.12,
#    'low': 64.77,
#    'close': 76.5,
#    'volume': 20076000.0,
#    'adj_open': 16.2125,
#    'adj_high': 20.03,
#    'adj_low': 16.1925,
#    'adj_close': 19.125,
#    'adj_volume': 80304000.0},
#   {'date': '2007-09-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 60.83,
#    'high': 67.8299,
#    'low': 60.78,
#    'close': 65.15,
#    'volume': 11582500.0,
#    'adj_open': 15.2075,
#    'adj_high': 16.957475,
#    'adj_low': 15.195,
#    'adj_close': 16.2875,
#    'adj_volume': 46330000.0},
#   {'date': '2007-08-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 58.0,
#    'high': 67.95,
#    'low': 55.8,
#    'close': 60.47,
#    'volume': 23240300.0,
#    'adj_open': 14.5,
#    'adj_high': 16.9875,
#    'adj_low': 13.95,
#    'adj_close': 15.1175,
#    'adj_volume': 92961200.0},
#   {'date': '2007-07-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 45.27,
#    'high': 60.24,
#    'low': 45.27,
#    'close': 58.16,
#    'volume': 24900700.0,
#    'adj_open': 11.3175,
#    'adj_high': 15.06,
#    'adj_low': 11.3175,
#    'adj_close': 14.54,
#    'adj_volume': 99602800.0},
#   {'date': '2007-06-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 48.6,
#    'high': 50.36,
#    'low': 43.49,
#    'close': 45.06,
#    'volume': 12511900.0,
#    'adj_open': 12.15,
#    'adj_high': 12.59,
#    'adj_low': 10.8725,
#    'adj_close': 11.265,
#    'adj_volume': 50047600.0},
#   {'date': '2007-05-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 42.5,
#    'high': 48.57,
#    'low': 40.95,
#    'close': 48.57,
#    'volume': 16054300.0,
#    'adj_open': 10.625,
#    'adj_high': 12.1425,
#    'adj_low': 10.2375,
#    'adj_close': 12.1425,
#    'adj_volume': 64217200.0},
#   {'date': '2007-04-30',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 43.14,
#    'high': 45.0,
#    'low': 41.72,
#    'close': 41.86,
#    'volume': 11629000.0,
#    'adj_open': 10.785,
#    'adj_high': 11.25,
#    'adj_low': 10.43,
#    'adj_close': 10.465,
#    'adj_volume': 46516000.0},
#   {'date': '2007-03-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 36.5,
#    'high': 45.78,
#    'low': 35.13,
#    'close': 43.24,
#    'volume': 25356300.0,
#    'adj_open': 9.125,
#    'adj_high': 11.445,
#    'adj_low': 8.7825,
#    'adj_close': 10.81,
#    'adj_volume': 101425200.0},
#   {'date': '2007-02-28',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 41.77,
#    'high': 42.88,
#    'low': 36.48,
#    'close': 36.88,
#    'volume': 10098900.0,
#    'adj_open': 10.4425,
#    'adj_high': 10.72,
#    'adj_low': 9.12,
#    'adj_close': 9.22,
#    'adj_volume': 40395600.0},
#   {'date': '2007-01-31',
#    'intraperiod': False,
#    'frequency': 'monthly',
#    'open': 40.49,
#    'high': 42.97,
#    'low': 38.62,
#    'close': 41.57,
#    'volume': 10045400.0,
#    'adj_open': 10.1225,
#    'adj_high': 10.7425,
#    'adj_low': 9.655,
#    'adj_close': 10.3925,
#    'adj_volume': 40181600.0}],
#  'security': {'id': 'sec_wy3kAy',
#   'company_id': 'com_5yd9Lg',
#   'stock_exchange_id': 'sxg_ozMr9y',
#   'name': 'Alexion Pharmaceuticals Inc.',
#   'code': 'EQS',
#   'currency': 'USD',
#   'ticker': 'ALXN',
#   'composite_ticker': 'ALXN:US',
#   'figi': 'BBG000G32HL2',
#   'composite_figi': 'BBG000G30YX4',
#   'share_class_figi': 'BBG001S8QH49'},
#  'next_page': None}

# %%
name = JSONContent["stock_prices"][1]["date"]
name
# Out:
# '2011-04-30'

# %%
data = {"stock": ticker_df, "date": date_df, "intraperiod": intraperiod_df, "frequency": frequency_df,
        "open": open_df,"high":high_df,"low":low_df,"close":close_df,"volume":volume_df,"adj_open":adj_open_df
        ,"adj_high":adj_high_df,"adj_low":adj_low_df,"adj_close":adj_close_df,"adj_volume":adj_volume_df }
   

prices_df = pd.DataFrame(data) 
prices_df
# Out:
#      stock        date  intraperiod frequency    open      high       low  \
# 0       KL  2019-09-30        False   monthly   49.80   51.0800   42.2900
# 1       KL  2019-08-31        False   monthly   40.66   51.0300   40.5000
# 2       KL  2019-07-31        False   monthly   41.28   47.2100   40.0500
# 3       KL  2019-06-30        False   monthly   35.47   44.0400   34.7036
# 4       KL  2019-05-31        False   monthly   32.19   35.2000   30.5700
# 5       KL  2019-04-30        False   monthly   30.35   33.3700   29.1500
# 6       KL  2019-03-31        False   monthly   36.20   36.6151   30.3750
# 7       KL  2019-02-28        False   monthly   32.03   36.7400   31.2000
# 8       KL  2019-01-31        False   monthly   26.17   32.1700   24.6900
# 9       KL  2018-12-31        False   monthly   21.29   26.4700   21.2900
