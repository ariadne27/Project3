# %%
import http.client
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# %%
sp500_df = pd.read_csv("../Data/s&p 500.csv") 
allco_df = pd.read_csv("../Data/Security_Details.csv")

# %%
sp500_df
# Out:
#     symbol                          Security             GICS Sector
# 0     ATVI               Activision Blizzard  Communication Services
# 1    GOOGL              Alphabet Inc Class A  Communication Services
# 2     GOOG              Alphabet Inc Class C  Communication Services
# 3        T                         AT&T Inc.  Communication Services
# 4      CBS                         CBS Corp.  Communication Services
# 5      CTL                   CenturyLink Inc  Communication Services
# 6     CHTR            Charter Communications  Communication Services
# 7    CMCSA                     Comcast Corp.  Communication Services
# 8    DISCA            Discovery Inc. Class A  Communication Services
# 9    DISCK            Discovery Inc. Class C  Communication Services
# 10    DISH                      Dish Network  Communication Services
# 11      EA                   Electronic Arts  Communication Services
# 12      FB                    Facebook, Inc.  Communication Services
# ...

# %%
allco_df
# Out:
#        Unnamed: 0                                  name  symbol  \
# 0               0                             Apple Inc    AAPL
# 1               1                      Exxon Mobil Corp     XOM
# 2               2                           Oracle Corp    ORCL
# 3               3                          Coca-Cola Co      KO
# 4               4                            Intel Corp    INTC
# 5               5                           Walmart Inc     WMT
# 6               6                        Microsoft Corp    MSFT
# 7               7  International Business Machines Corp     IBM
# 8               8                          Chevron Corp     CVX
# 9               9                     Johnson & Johnson     JNJ
# 10             10                   Walt Disney Co, The     DIS
# 11             11                           PepsiCo Inc     PEP
# 12             12                   Procter & Gamble Co      PG
# 13             13                            Pfizer Inc     PFE
# ...

# %%
result = pd.merge(allco_df , sp500_df, on='symbol', how='left')
result
# Out:
#        Unnamed: 0                                  name  symbol  \
# 0               0                             Apple Inc    AAPL
# 1               1                      Exxon Mobil Corp     XOM
# 2               2                           Oracle Corp    ORCL
# 3               3                          Coca-Cola Co      KO
# 4               4                            Intel Corp    INTC
# 5               5                           Walmart Inc     WMT
# 6               6                        Microsoft Corp    MSFT
# 7               7  International Business Machines Corp     IBM
# 8               8                          Chevron Corp     CVX
# 9               9                     Johnson & Johnson     JNJ
# 10             10                   Walt Disney Co, The     DIS
# 11             11                           PepsiCo Inc     PEP
# 12             12                   Procter & Gamble Co      PG
# 13             13                            Pfizer Inc     PFE
# ...

# %%
result.to_csv(r'AllCo_SP500.csv')

# %%
result2 = pd.merge(sp500_df, allco_df ,  on='symbol', how='left')
result2
# Out:
#     symbol                          Security             GICS Sector  \
# 0     ATVI               Activision Blizzard  Communication Services
# 1    GOOGL              Alphabet Inc Class A  Communication Services
# 2     GOOG              Alphabet Inc Class C  Communication Services
# 3        T                         AT&T Inc.  Communication Services
# 4      CBS                         CBS Corp.  Communication Services
# 5      CTL                   CenturyLink Inc  Communication Services
# 6     CHTR            Charter Communications  Communication Services
# 7    CMCSA                     Comcast Corp.  Communication Services
# 8    DISCA            Discovery Inc. Class A  Communication Services
# 9    DISCK            Discovery Inc. Class C  Communication Services
# 10    DISH                      Dish Network  Communication Services
# 11      EA                   Electronic Arts  Communication Services
# 12      FB                    Facebook, Inc.  Communication Services
# ...

# %%
filtered_df = result2[result2['name'].isnull()]
filtered_df
# Out:
#     symbol                 Security             GICS Sector  Unnamed: 0 name  \
# 2     GOOG     Alphabet Inc Class C  Communication Services         NaN  NaN
# 9    DISCK   Discovery Inc. Class C  Communication Services         NaN  NaN
# 15     FOX  Fox Corporation Class B  Communication Services         NaN  NaN
# 19     NWS       News Corp. Class B  Communication Services         NaN  NaN
# 26    VIAB              Viacom Inc.  Communication Services         NaN  NaN
# 86     UAA     Under Armour Class A  Consumer Discretionary         NaN  NaN
# 94    BF.B       Brown-Forman Corp.        Consumer Staples         NaN  NaN
# 165  BRK.B       Berkshire Hathaway              Financials         NaN  NaN
# 182     GL          Globe Life Inc.              Financials         NaN  NaN
# 320    LHX    L3Harris Technologies             Industrials         NaN  NaN
#
#     sector legal_name stock_exchange  sic short_description company_url  \
# ...

# %%
filtered_df.to_csv(r'Missing SP500 in Master Set.csv')
